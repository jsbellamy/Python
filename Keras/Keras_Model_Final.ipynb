# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import *

training_data_df = pd.read_csv("sales_data_training_scaled.csv")

X = training_data_df.drop('total_earnings', axis=1).values
Y = training_data_df[['total_earnings']].values

# Define the model
model = Sequential()
model.add(Dense(50, input_dim=9, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(X, Y, epochs=50, shuffle=True, verbose=2)

# Load the separate test data set
test_data_df = pd.read_csv("sales_data_test_scaled.csv")

X_test = test_data_df.drop('total_earnings', axis=1).values
Y_test = test_data_df[['total_earnings']].values

test_error_rate = model.evaluate(X_test, Y_test, verbose=0)
print("The mean squared error (MSE) for the test data set is: {}".format(test_error_rate))

model.save('trained_model.h5')
print('Model saved to disk.')
# Out:
# Epoch 1/50
#  - 0s - loss: 0.0325
# Epoch 2/50
#  - 0s - loss: 0.0044
# Epoch 3/50
#  - 0s - loss: 0.0013
# Epoch 4/50
#  - 0s - loss: 6.1092e-04
# Epoch 5/50
#  - 0s - loss: 3.6384e-04
# Epoch 6/50
#  - 0s - loss: 2.5618e-04
# Epoch 7/50
#  - 0s - loss: 1.9364e-04
# Epoch 8/50
#  - 0s - loss: 1.4792e-04
# Epoch 9/50
#  - 0s - loss: 1.2635e-04
# Epoch 10/50
#  - 0s - loss: 1.0278e-04
# Epoch 11/50
#  - 0s - loss: 8.7617e-05
# Epoch 12/50
#  - 0s - loss: 7.7692e-05
# Epoch 13/50
#  - 0s - loss: 7.7792e-05
# Epoch 14/50
#  - 0s - loss: 5.6552e-05
# Epoch 15/50
#  - 0s - loss: 5.0357e-05
# Epoch 16/50
#  - 0s - loss: 4.1774e-05
# Epoch 17/50
#  - 0s - loss: 4.3331e-05
# Epoch 18/50
#  - 0s - loss: 3.8607e-05
# Epoch 19/50
#  - 0s - loss: 3.2997e-05
# Epoch 20/50
#  - 0s - loss: 3.6747e-05
# Epoch 21/50
#  - 0s - loss: 2.9514e-05
# Epoch 22/50
#  - 0s - loss: 2.8759e-05
# Epoch 23/50
#  - 0s - loss: 2.7284e-05
# Epoch 24/50
#  - 0s - loss: 2.5176e-05
# Epoch 25/50
#  - 0s - loss: 3.0228e-05
# Epoch 26/50
#  - 0s - loss: 3.2892e-05
# Epoch 27/50
#  - 0s - loss: 2.3860e-05
# Epoch 28/50
#  - 0s - loss: 3.2641e-05
# Epoch 29/50
#  - 0s - loss: 4.0490e-05
# Epoch 30/50
#  - 0s - loss: 2.5675e-05
# Epoch 31/50
#  - 0s - loss: 2.3297e-05
# Epoch 32/50
#  - 0s - loss: 2.0612e-05
# Epoch 33/50
#  - 0s - loss: 1.9087e-05
# Epoch 34/50
#  - 0s - loss: 2.0880e-05
# Epoch 35/50
#  - 0s - loss: 1.9419e-05
# Epoch 36/50
#  - 0s - loss: 2.0726e-05
# Epoch 37/50
#  - 0s - loss: 1.9756e-05
# Epoch 38/50
#  - 0s - loss: 2.0654e-05
# Epoch 39/50
#  - 0s - loss: 2.0636e-05
# Epoch 40/50
#  - 0s - loss: 1.6456e-05
# Epoch 41/50
#  - 0s - loss: 2.4353e-05
# Epoch 42/50
#  - 0s - loss: 2.1101e-05
# Epoch 43/50
#  - 0s - loss: 1.8262e-05
# Epoch 44/50
#  - 0s - loss: 1.7968e-05
# Epoch 45/50
#  - 0s - loss: 1.8613e-05
# Epoch 46/50
#  - 0s - loss: 1.8172e-05
# Epoch 47/50
#  - 0s - loss: 1.4678e-05
# Epoch 48/50
#  - 0s - loss: 1.5996e-05
# Epoch 49/50
#  - 0s - loss: 1.8233e-05
# Epoch 50/50
#  - 0s - loss: 1.6742e-05
# The mean squared error (MSE) for the test data set is: 6.103700055973605e-05
# Model saved to disk.

# %%
import pandas as pd
from keras.models import Sequential
from keras.layers import *

training_data_df = pd.read_csv("sales_data_training_scaled.csv")

X = training_data_df.drop('total_earnings', axis=1).values
Y = training_data_df[['total_earnings']].values

# Define the model
model = Sequential()
model.add(Dense(50, input_dim=9, activation='relu'))
model.add(Dense(100, activation='relu'))
model.add(Dense(50, activation='relu'))
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam')

# Train the model
model.fit(
    X,
    Y,
    epochs=50,
    shuffle=True,
    verbose=2
)

# Load the separate test data set
test_data_df = pd.read_csv("sales_data_test_scaled.csv")

X_test = test_data_df.drop('total_earnings', axis=1).values
Y_test = test_data_df[['total_earnings']].values

test_error_rate = model.evaluate(X_test, Y_test, verbose=0)
print("The mean squared error (MSE) for the test data set is: {}".format(test_error_rate))

# Load the data we make to use to make a prediction
X = pd.read_csv("proposed_new_product.csv").values

# Make a prediction with the neural network
prediction = model.predict(X)

# Grab just the first element of the first prediction (since that's the only have one)
prediction = prediction[0][0]

# Re-scale the data from the 0-to-1 range back to dollars
# These constants are from when the data was originally scaled down to the 0-to-1 range
prediction = prediction + 0.1159
prediction = prediction / 0.0000036968

print("Earnings Prediction for Proposed Product - ${}".format(prediction))
# Out:
# Epoch 1/50
#  - 0s - loss: 0.0387
# Epoch 2/50
#  - 0s - loss: 0.0063
# Epoch 3/50
#  - 0s - loss: 0.0022
# Epoch 4/50
#  - 0s - loss: 0.0011
# Epoch 5/50
#  - 0s - loss: 6.0758e-04
# Epoch 6/50
#  - 0s - loss: 3.9418e-04
# Epoch 7/50
#  - 0s - loss: 2.6973e-04
# Epoch 8/50
#  - 0s - loss: 1.8963e-04
# Epoch 9/50
#  - 0s - loss: 1.4195e-04
# Epoch 10/50
#  - 0s - loss: 1.2791e-04
# Epoch 11/50
#  - 0s - loss: 9.2804e-05
# Epoch 12/50
#  - 0s - loss: 8.3502e-05
# Epoch 13/50
#  - 0s - loss: 6.7666e-05
# Epoch 14/50
#  - 0s - loss: 6.6267e-05
# Epoch 15/50
#  - 0s - loss: 5.6670e-05
# Epoch 16/50
#  - 0s - loss: 5.7213e-05
# Epoch 17/50
#  - 0s - loss: 5.5733e-05
# Epoch 18/50
#  - 0s - loss: 4.2852e-05
# Epoch 19/50
#  - 0s - loss: 4.6807e-05
# Epoch 20/50
#  - 0s - loss: 4.2849e-05
# Epoch 21/50
#  - 0s - loss: 4.5486e-05
# Epoch 22/50
#  - 0s - loss: 4.6046e-05
# Epoch 23/50
#  - 0s - loss: 4.2167e-05
# Epoch 24/50
#  - 0s - loss: 3.5747e-05
# Epoch 25/50
#  - 0s - loss: 2.6501e-05
# Epoch 26/50
#  - 0s - loss: 3.2672e-05
# Epoch 27/50
#  - 0s - loss: 3.4725e-05
# Epoch 28/50
#  - 0s - loss: 2.8067e-05
# Epoch 29/50
#  - 0s - loss: 2.5616e-05
# Epoch 30/50
#  - 0s - loss: 2.6117e-05
# Epoch 31/50
#  - 0s - loss: 2.2421e-05
# Epoch 32/50
#  - 0s - loss: 2.4012e-05
# Epoch 33/50
#  - 0s - loss: 2.5768e-05
# Epoch 34/50
#  - 0s - loss: 2.7225e-05
# Epoch 35/50
#  - 0s - loss: 2.1722e-05
# Epoch 36/50
#  - 0s - loss: 2.3025e-05
# Epoch 37/50
#  - 0s - loss: 2.8452e-05
# Epoch 38/50
#  - 0s - loss: 4.3066e-05
# Epoch 39/50
#  - 0s - loss: 2.2676e-05
# Epoch 40/50
#  - 0s - loss: 2.3458e-05
# Epoch 41/50
#  - 0s - loss: 3.7353e-05
# Epoch 42/50
#  - 0s - loss: 4.6208e-05
# Epoch 43/50
#  - 0s - loss: 3.2938e-05
# Epoch 44/50
#  - 0s - loss: 2.5361e-05
# Epoch 45/50
#  - 0s - loss: 2.1380e-05
# Epoch 46/50
#  - 0s - loss: 3.3092e-05
# Epoch 47/50
#  - 0s - loss: 2.3824e-05
# Epoch 48/50
#  - 0s - loss: 2.1099e-05
# Epoch 49/50
#  - 0s - loss: 3.0119e-05
# Epoch 50/50
#  - 0s - loss: 2.1521e-05
# The mean squared error (MSE) for the test data set is: 9.2737265949836e-05
# Earnings Prediction for Proposed Product - $265084.7783776956

# %%
import pandas as pd
from keras.models import load_model

model = load_model('trained_model.h5')

X = pd.read_csv("proposed_new_product.csv").values
prediction = model.predict(X)

# Grab just the first element of the first prediction (since we only have one)
prediction = prediction[0][0]

# Re-scale the data from the 0-to-1 range back to dollars
# These constants are from when the data was originally scaled down to the 0-to-1 range
prediction = prediction + 0.1159
prediction = prediction / 0.0000036968

print("Earnings Prediction for Proposed Product - ${}".format(prediction))
# Out:
# Earnings Prediction for Proposed Product - $266370.3219659967
